# %% [markdown]
# # Outputs Dimmension-tables
# Provides outputs for summary data

# %%
import pandas as pd
import csv

# contains 2016-2017 and 2017-2018
dimensions1_df = pd.read_csv("./ELSI_csv_export_6374253004417906414779.csv")
print("Columns: ", dimensions1_df.columns.values, "\n" )
# Out:
# Columns:  ['School Name' 'State Name [Public School] Latest available year'
#  'State Name [Public School] 2018-19' 'State Name [Public School] 2017-18'
#  'State Name [Public School] 2016-17'
#  'State Abbr [Public School] Latest available year'
#  'School Name [Public School] 2018-19'
#  'School Name [Public School] 2017-18'
#  'School Name [Public School] 2016-17'
#  'County Name [Public School] 2018-19'
#  'County Name [Public School] 2017-18'
#  'County Name [Public School] 2016-17'
#  'Total Students All Grades (Excludes AE) [Public School] 2018-19'
#  'Total Students All Grades (Excludes AE) [Public School] 2017-18'
#  'Total Students All Grades (Excludes AE) [Public School] 2016-17'
#  'Total Students All Grades (Includes AE) [Public School] 2018-19'
#  'Total Students All Grades (Includes AE) [Public School] 2017-18'
#  'Total Students All Grades (Includes AE) [Public School] 2016-17'
#  'Free Lunch Eligible [Public School] 2018-19'
# ...

# %%
dimensions1_df
# Out:
#                                               School Name  \
# 0                         1 LT CHARLES W. WHITCOMB SCHOOL
# 1                                      10TH STREET SCHOOL
# 2                               112 ALC INDEPENDENT STUDY
# 3                                   112 ALC MIDDLE SCHOOL
# 4                                      112 ALC SEAT-BASED
# ...                                                   ...
# 103985  Data Source: U.S. Department of Education Nati...
# 103986                                                NaN
# 103987      † indicates that the data are not applicable.
# 103988             – indicates that the data are missing.
# 103989  ‡ indicates that the data do not meet NCES dat...
#
#        State Name [Public School] Latest available year  \
# 0                                         Massachusetts
# 1                                            Washington
# 2                                             Minnesota
# ...
