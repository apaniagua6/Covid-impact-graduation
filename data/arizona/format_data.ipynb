# %%
# data from https://www.azed.gov/accountability-research/data 

import pandas as pd
import glob
import os


az_enrollment_2020_gender = pd.read_csv("data/AZ/2020/LEA by Gender-Table 1.csv")
az_enrollment_2020_gender
df_gender = pd.DataFrame(az_enrollment_2020_gender)

az_enrollment_2020_grade = pd.read_csv("data/AZ/2020/School by Grade-Table 1.csv")
az_enrollment_2020_grade
df_grade_2020 = pd.DataFrame(az_enrollment_2020_grade)

df_grade_2020.head(5)
df_grade_2020.tail(5)
# Out:
#       Fiscal Year                         LEA Name  LEA Entity ID  \
# 2245         2020  Yuma Union High School District           4507
# 2246         2020  Yuma Union High School District           4507
# 2247         2020  Yuma Union High School District           4507
# 2248         2020  Yuma Union High School District           4507
# 2249         2020  Yuma Union High School District           4507
#
#                        School Name  School Entity ID PS KG  1  2  3  4  5  6  \
# 2245              Kofa High School              6190  *  *  *  *  *  *  *  *
# 2246          San Luis High School             80409  *  *  *  *  *  *  *  *
# 2247             Vista High School              6302  *  *  *  *  *  *  *  *
# 2248              Yuma High School              6189  *  *  *  *  *  *  *  *
# 2249  Yuma Online Distance Academy             91316  *  *  *  *  *  *  *  *
#
#       7  8    9   10   11   12 Total
# 2245  *  *  693  647  606  567  2513
# ...

# %%
az_enrollment_2019_gender = pd.read_csv("data/AZ/2019/LEA by Gender-Table 1.csv")
az_enrollment_2019_gender
df_gender_2019 = pd.DataFrame(az_enrollment_2019_gender)

az_enrollment_2019_grade = pd.read_csv("data/AZ/2019/School by Grade-Table 1.csv")
az_enrollment_2019_grade
df_grade_2019 = pd.DataFrame(az_enrollment_2019_grade)

df_grade_2019.head(5)
df_grade_2019.tail(5)
# Out:
#       Fiscal Year                         LEA Name  LEA Entity ID  \
# 1966         2019  Yuma Union High School District           4507
# 1967         2019  Yuma Union High School District           4507
# 1968         2019  Yuma Union High School District           4507
# 1969         2019  Yuma Union High School District           4507
# 1970         2019  Yuma Union High School District           4507
#
#                        School Name  School Entity ID PS KG  1  2  3  4  5  6  \
# 1966            Cibola High School              6191  *  *  *  *  *  *  *  *
# 1967      Vista Alternative School              6302  *  *  *  *  *  *  *  *
# 1968          San Luis High School             80409  *  *  *  *  *  *  *  *
# 1969        Gila Ridge High School             89576  *  *  *  *  *  *  *  *
# 1970  Yuma Online Distance Academy             91316  *  *  *  *  *  *  *  *
#
#       7  8    9   10   11   12 Total
# 1966  *  *  666  660  638  597  2561
# ...

# %%
az_enrollment_2018_gender = pd.read_csv("data/AZ/2018/LEA by Gender-Table 1.csv")
az_enrollment_2018_gender
df_gender_2018 = pd.DataFrame(az_enrollment_2020_gender)

az_enrollment_2018_grade = pd.read_csv("data/AZ/2018/School by Grade-Table 1.csv")
az_enrollment_2018_grade
df_grade_2018 = pd.DataFrame(az_enrollment_2018_grade)

df_grade_2018.head(5)
df_grade_2018.tail(5)
# Out:
#       Fiscal Year                         LEA Name  LEA Entity ID  \
# 1966         2019  Yuma Union High School District           4507
# 1967         2019  Yuma Union High School District           4507
# 1968         2019  Yuma Union High School District           4507
# 1969         2019  Yuma Union High School District           4507
# 1970         2019  Yuma Union High School District           4507
#
#                        School Name  School Entity ID PS KG  1  2  3  4  5  6  \
# 1966            Cibola High School              6191  *  *  *  *  *  *  *  *
# 1967      Vista Alternative School              6302  *  *  *  *  *  *  *  *
# 1968          San Luis High School             80409  *  *  *  *  *  *  *  *
# 1969        Gila Ridge High School             89576  *  *  *  *  *  *  *  *
# 1970  Yuma Online Distance Academy             91316  *  *  *  *  *  *  *  *
#
#       7  8    9   10   11   12 Total
# 1966  *  *  666  660  638  597  2561
# ...

# %%
az_enrollment_2017_gender = pd.read_csv("data/AZ/2017/LEA by Gender-Table 1.csv")
az_enrollment_2017_gender
df_gender_2017 = pd.DataFrame(az_enrollment_2017_gender)

az_enrollment_2017_grade = pd.read_csv("data/AZ/2017/School by Grade-Table 1.csv")
az_enrollment_2017_grade
df_grade_2017 = pd.DataFrame(az_enrollment_2017_grade)

df_grade_2017.head(5)
df_grade_2017.tail(5)
# Out:
#       Fiscal Year                         LEA Name  LEA Entity ID  \
# 2008         2018  Yuma Union High School District           4507
# 2009         2018  Yuma Union High School District           4507
# 2010         2018  Yuma Union High School District           4507
# 2011         2018  Yuma Union High School District           4507
# 2012         2018  Yuma Union High School District           4507
#
#                        School Name  School Entity ID PS KG  1  2  3  4  5  6  \
# 2008              Kofa High School              6190  *  *  *  *  *  *  *  *
# 2009          San Luis High School             80409  *  *  *  *  *  *  *  *
# 2010      Vista Alternative School              6302  *  *  *  *  *  *  *  *
# 2011              Yuma High School              6189  *  *  *  *  *  *  *  *
# 2012  Yuma Online Distance Academy             91316  *  *  *  *  *  *  *  *
#
#       7  8    9   10   11   12 Total
# 2008  *  *  632  574  527  541  2274
# ...

# %%
az_enrollment_2016_gender = pd.read_csv("data/AZ/2016/SchoolbyGender-Table 1.csv")
az_enrollment_2016_gender
df_gender_2016 = pd.DataFrame(az_enrollment_2016_gender)

az_enrollment_2016_grade = pd.read_csv("data/AZ/2016/SchoolbyGrade-Table 1.csv")
az_enrollment_2016_grade
df_grade_2016 = pd.DataFrame(az_enrollment_2016_grade)

#renaming columns as the state used a different naming convention for that year
df_grade_2016.rename({'October 1, 2016 Enrollment: School by Grade':'District of Residence Entity Name'}, axis=1, inplace=True)
df_grade_2016.rename({'Unnamed: 1':'District of Residence Entity ID'}, axis=1, inplace=True)
df_grade_2016.rename({'Unnamed: 2':'School Entity Name'}, axis=1, inplace=True)
df_grade_2016.rename({'Unnamed: 3':'School Entity ID'}, axis=1, inplace=True)
df_grade_2016.rename({'Unnamed: 4':'School CTDS'}, axis=1, inplace=True)
df_grade_2016.rename({'Unnamed: 5':'PS'}, axis=1, inplace=True)
df_grade_2016.rename({'Unnamed: 6':'KG'}, axis=1, inplace=True)
df_grade_2016.rename({'Unnamed: 7':'1'}, axis=1, inplace=True)
df_grade_2016.rename({'Unnamed: 8':'2'}, axis=1, inplace=True)
df_grade_2016.rename({'Unnamed: 9':'3'}, axis=1, inplace=True)
df_grade_2016.rename({'Unnamed: 10':'4'}, axis=1, inplace=True)
df_grade_2016.rename({'Unnamed: 11':'5'}, axis=1, inplace=True)
df_grade_2016.rename({'Unnamed: 12':'6'}, axis=1, inplace=True)
df_grade_2016.rename({'Unnamed: 13':'7'}, axis=1, inplace=True)
df_grade_2016.rename({'Unnamed: 14':'8'}, axis=1, inplace=True)
df_grade_2016.rename({'Unnamed: 15':'9'}, axis=1, inplace=True)
df_grade_2016.rename({'Unnamed: 16':'10'}, axis=1, inplace=True)
df_grade_2016.rename({'Unnamed: 17':'11'}, axis=1, inplace=True)
df_grade_2016.rename({'Unnamed: 18':'12'}, axis=1, inplace=True)
df_grade_2016.rename({'Unnamed: 19':'Total'}, axis=1, inplace=True)


df_grade_2016.head(5)
df_grade_2016.tail(5)
# Out:
#      District of Residence Entity Name District of Residence Entity ID  \
# 3374   Yuma Union High School District                            4507
# 3375   Yuma Union High School District                            4507
# 3376   Yuma Union High School District                            4507
# 3377   Yuma Union High School District                            4507
# 3378   Yuma Union High School District                            4507
#
#                 School Entity Name School Entity ID School CTDS PS KG  1  2  \
# 3374          San Luis High School            80409   140570205  *  *  *  *
# 3375            THE NEW FOUNDATION             7333   072135001  *  *  *  *
# 3376      Vista Alternative School             6302   140570204  *  *  *  *
# 3377              Yuma High School             6189   140570201  *  *  *  *
# 3378  Yuma Online Distance Academy            91316   140570301  *  *  *  *
#
#       3     ...      5  6  7  8    9   10   11   12 Total Unnamed: 20
# ...

# %%
# appending data for all years
df_az_grades_2016_2020 = pd.DataFrame()

df_az_grades_2016_2020 = df_az_grades_2016_2020.append(df_grade_2020)
df_az_grades_2016_2020 = df_az_grades_2016_2020.append(df_grade_2019, sort=False)


# fixme: cant append addiotnoal years even when columns are the same
df_az_grades_2016_2020.head(5) 
df_az_grades_2016_2020.tail(5)
# Out:
#       Fiscal Year                         LEA Name  LEA Entity ID  \
# 1966         2019  Yuma Union High School District           4507
# 1967         2019  Yuma Union High School District           4507
# 1968         2019  Yuma Union High School District           4507
# 1969         2019  Yuma Union High School District           4507
# 1970         2019  Yuma Union High School District           4507
#
#                        School Name  School Entity ID PS KG    1    2  3 ...  \
# 1966            Cibola High School              6191  *  *  NaN  NaN  * ...
# 1967      Vista Alternative School              6302  *  *  NaN  NaN  * ...
# 1968          San Luis High School             80409  *  *  NaN  NaN  * ...
# 1969        Gila Ridge High School             89576  *  *  NaN  NaN  * ...
# 1970  Yuma Online Distance Academy             91316  *  *  NaN  NaN  * ...
#
#       6  7  8    9   10   11   12 Total  1  2
# 1966  *  *  *  666  660  638  597  2561  *  *
# ...

# %%
# remove grades that are not high shcool high school (columns for grades not 9-12)
df_grade.drop(list(df_grade)[4:14], axis=1, inplace=True)
df_grade.head(20)
# Out:
#     Fiscal Year                                           LEA Name  \
# 3          2020               Academy of Building Industries, Inc.
# 9          2020                            Academy of Tucson, Inc.
# 11         2020               Academy with Community Partners  Inc
# 13         2020                                              ACCEL
# 14         2020                                              ACCEL
# 16         2020       Accelerated Elementary and Secondary Schools
# 17         2020                  Accelerated Learning Center, Inc.
# 21         2020               Agua Fria Union High School District
# 22         2020               Agua Fria Union High School District
# 23         2020               Agua Fria Union High School District
# 24         2020               Agua Fria Union High School District
# 25         2020               Agua Fria Union High School District
# 27         2020      AIBT Non-Profit Charter High School - Phoenix
# ...

# %%
# remove schools that are not high shcool high school (value for grades 9-12 == *)
index_grade = df_grade[(df_grade['9']=='*') & (df_grade['10']=='*') & (df_grade['11']=='*') &(df_grade['12']=='*')].index
df_grade.drop(index_grade, inplace=True)
df_grade.head(5)
# Out:
#     Fiscal Year                              LEA Name  LEA Entity ID  \
# 3          2020  Academy of Building Industries, Inc.          85540
# 9          2020               Academy of Tucson, Inc.          78897
# 11         2020  Academy with Community Partners  Inc          79213
# 13         2020                                 ACCEL           7355
# 14         2020                                 ACCEL           7355
#
#                         School Name  School Entity ID   9  10  11  12 Total
# 3    Academy of Building Industries             85541   *  22  35  47   110
# 9     Academy of Tucson High School             78898  50  49  27  29   155
# 11  Academy with Community Partners             10795   *  18  27  81   132
# 13                ACCEL East Campus              7360   *   *   *  19    62
# 14               ACCEL Metro Campus              7356  12   *  17  31   112

# %%
# add state to df to match schema
state = 'Arizona'
df_grade['State'] = state
df_grade.head(5)
# Out:
#     Fiscal Year                              LEA Name  LEA Entity ID  \
# 3          2020  Academy of Building Industries, Inc.          85540
# 9          2020               Academy of Tucson, Inc.          78897
# 11         2020  Academy with Community Partners  Inc          79213
# 13         2020                                 ACCEL           7355
# 14         2020                                 ACCEL           7355
#
#                         School Name  School Entity ID   9  10  11  12 Total  \
# 3    Academy of Building Industries             85541   *  22  35  47   110
# 9     Academy of Tucson High School             78898  50  49  27  29   155
# 11  Academy with Community Partners             10795   *  18  27  81   132
# 13                ACCEL East Campus              7360   *   *   *  19    62
# 14               ACCEL Metro Campus              7356  12   *  17  31   112
#
#       State
# 3   Arizona
# 9   Arizona
# 11  Arizona
# 13  Arizona
# 14  Arizona

# %%
# add missing columns to data to match schema

# %%
# renaming existing columns to match schema
df_gender.rename(columns={'School District':'School Name'}, inplace=True)
df_gender.head(5)
# Out:
#    Fiscal Year                                    School Name  LEA Entity ID  \
# 0         2020                                        Arizona            NaN
# 1         2020                A Center for Creative Education        79457.0
# 2         2020                                          ACCEL         7355.0
# 3         2020  AIBT Non-Profit Charter High School - Phoenix        79053.0
# 4         2020      AIBT Non-Profit Charter High School, Inc.       449790.0
#
#    Female    Male Total    state    State
# 0  561194  589793     *  Arizona  Arizona
# 1      33      34    67  Arizona  Arizona
# 2      43     152   195  Arizona  Arizona
# 3      51      52   103  Arizona  Arizona
# 4       *       *     *  Arizona  Arizona
